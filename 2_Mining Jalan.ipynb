# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = "https://raw.githubusercontent.com/fahmiagungmaulana/data1/main/train.csv"
train = pd.read_csv(url)

# %%
train.head()
# Out:
#               waktu_setempat   id_jalan  id_titik_mulai  id_titik_akhir  \
# 0  2020-02-01 01:00:00+00:00  691007296        21390008      1425033102
# 1  2020-02-01 01:00:00+00:00   47010584      1677092762       579493410
# 2  2020-02-01 01:00:00+00:00   22932408        26486694      1930267566
# 3  2020-02-01 01:00:00+00:00  142479648      1111592522      3775231113
# 4  2020-02-01 01:00:00+00:00    8504977      5940503398      5940503394
#
#    rerata_kecepatan
# 0            29.126
# 1            46.576
# 2            36.587
# 3            34.063
# 4            38.336

# %% [markdown]
# #Mining Jalan

# %%
train.id_jalan.nunique()
# Out:
# 20

# %%
train.id_jalan.unique()
# Out:
# array([691007296,  47010584,  22932408, 142479648,   8504977,  50841260,
#          4060819,  24704286,   4061596,   4004732,   3688059,  66924592,
#          3691841,  97453767,   4898588,  26785612, 182210371, 150783571,
#         40044423,      1210])

# %%
data = {
    'id': [691007296, 47010584, 22932408, 142479648, 8504977, 50841260, 4060819, 24704286, 4061596, 4004732, 3688059, 66924592, 3691841, 97453767, 4898588, 26785612, 182210371, 150783571, 40044423, 1210],
    'maxspeed_mph': [30, 30, 20, 20, 30, 30, 20, 30, 20, 30, 30, 30, 30, 20, 20, 20, 30, 30, 30, 30]
}

df_jalan = pd.DataFrame(data)

# %%
df_jalan['maxspeed_mph'] = df_jalan['maxspeed_mph'].astype(str)

# %%
df_jalan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            20 non-null     int64
#  1   maxspeed_mph  20 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 448.0+ bytes

# %%
df_jalan.to_csv("df_jalan.csv", index=False)
